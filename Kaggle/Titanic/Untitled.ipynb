# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn import linear_model
import numpy as np

# %%
def loadCsv(fileName=None):
	if fileName == None:
		print('Error: file is not exist!')
	else:
		dataTrain = pd.read_csv(fileName)
		return dataTrain

# %%
dataTrain = loadCsv('train.csv')	
dataTest = loadCsv('test.csv')

dataTrain['Age'] = dataTrain['Age'].fillna(dataTrain['Age'].median()) # 插入平均值

dataTrain.loc[dataTrain['Sex'] == 'male', 'Sex'] = 0
dataTrain.loc[dataTrain['Sex'] == 'female', 'Sex'] = 1

dataTrain.loc[dataTrain['Embarked'] == 'S', 'Embarked'] = 0
dataTrain.loc[dataTrain['Embarked'] == 'Q', 'Embarked'] = 1
dataTrain.loc[dataTrain['Embarked'] == 'C', 'Embarked'] = 2

# %%
dataTrain
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
	dataTrain['Fare'] = (dataTrain['Fare'] - dataTrain['Fare'].min()) / (dataTrain['Fare'].max() - dataTrain['Fare'].min())

# %%
dataTrain
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
dataTrain = loadCsv('train.csv')	
	dataTest = loadCsv('test.csv')

	dataTrain['Age'] = dataTrain['Age'].fillna(dataTrain['Age'].median()) # 插入平均值
	dataTrain['Age'] = (dataTrain['Age'] - dataTrain['Age'].min()) / (dataTrain['Age'].max() - dataTrain['Age'].min())

	dataTrain.loc[dataTrain['Sex'] == 'male', 'Sex'] = 0
	dataTrain.loc[dataTrain['Sex'] == 'female', 'Sex'] = 1

	dataTrain.loc[dataTrain['Embarked'] == 'S', 'Embarked'] = 0
	dataTrain.loc[dataTrain['Embarked'] == 'Q', 'Embarked'] = 1
	dataTrain.loc[dataTrain['Embarked'] == 'C', 'Embarked'] = 2

	dataTrain['Fare'] = (dataTrain['Fare'] - dataTrain['Fare'].min()) / (dataTrain['Fare'].max() - dataTrain['Fare'].min())

	predictors = ['Pclass', 'Sex', 'Fare', 'Embarked', 'Age']
# Out:
#   File "<ipython-input-7-0c1a79a6b0c0>", line 2
#     dataTest = loadCsv('test.csv')
#     ^
# IndentationError: unexpected indent

# %%
dataTrain = loadCsv('train.csv')	
dataTest = loadCsv('test.csv')

dataTrain['Age'] = dataTrain['Age'].fillna(dataTrain['Age'].median()) # 插入平均值
dataTrain['Age'] = (dataTrain['Age'] - dataTrain['Age'].min()) / (dataTrain['Age'].max() - dataTrain['Age'].min())

dataTrain.loc[dataTrain['Sex'] == 'male', 'Sex'] = 0
dataTrain.loc[dataTrain['Sex'] == 'female', 'Sex'] = 1

dataTrain.loc[dataTrain['Embarked'] == 'S', 'Embarked'] = 0
dataTrain.loc[dataTrain['Embarked'] == 'Q', 'Embarked'] = 1
dataTrain.loc[dataTrain['Embarked'] == 'C', 'Embarked'] = 2

dataTrain['Fare'] = (dataTrain['Fare'] - dataTrain['Fare'].min()) / (dataTrain['Fare'].max() - dataTrain['Fare'].min())

predictors = ['Pclass', 'Sex', 'Fare', 'Embarked', 'Age']

# %%
dataTrain
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
from sklearn.svm import SVC

# %%
partDatatrain = dataTrain[predictors]

# %%
partDatatrain
# Out:
#      Pclass  Sex      Fare Embarked       Age
# 0         3    0  0.014151        0  0.271174
# 1         1    1  0.139136        2  0.472229
# 2         3    1  0.015469        0  0.321438
# 3         1    1  0.103644        0  0.434531
# 4         3    0  0.015713        0  0.434531
# 5         3    0  0.016510        1  0.346569
# 6         1    0  0.101229        0  0.673285
# 7         3    0  0.041136        0  0.019854
# 8         3    1  0.021731        0  0.334004
# 9         2    1  0.058694        2  0.170646
# 10        3    1  0.032596        0  0.044986
# 11        1    1  0.051822        0  0.723549
# 12        3    0  0.015713        0  0.246042
# 13        3    0  0.061045        0  0.484795
# 14        3    1  0.015330        0  0.170646
# 15        2    1  0.031230        0  0.685851
# 16        3    0  0.056848        1  0.019854
# 17        2    0  0.025374        0  0.346569
# 18        3    1  0.035134        0  0.384267
# ...

# %%
clf = SVC()
	clf.fit(dataTrain[predictors], dataTrain['Survived'])
# Out:
#   File "<ipython-input-13-33a1541d122a>", line 2
#     clf.fit(dataTrain[predictors], dataTrain['Survived'])
#     ^
# IndentationError: unexpected indent

# %%
clf = SVC()
clf.fit(dataTrain[predictors], dataTrain['Survived'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-0bc0ff1f0949> in <module>()
#       1 clf = SVC()
# ----> 2 clf.fit(dataTrain[predictors], dataTrain['Survived'])
#
# /usr/local/lib/python3.6/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
datatrain['Survived']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-38b630da7375> in <module>()
# ----> 1 datatrain['Survived']
#
# NameError: name 'datatrain' is not defined

# %%
dataTrain['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
clf.fit(dataTrain[predictors], dataTrain['Survived'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-a8384402a1a0> in <module>()
# ----> 1 clf.fit(dataTrain[predictors], dataTrain['Survived'])
#
# /usr/local/lib/python3.6/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
dataTrain[predictors]
# Out:
#      Pclass  Sex      Fare Embarked       Age
# 0         3    0  0.014151        0  0.271174
# 1         1    1  0.139136        2  0.472229
# 2         3    1  0.015469        0  0.321438
# 3         1    1  0.103644        0  0.434531
# 4         3    0  0.015713        0  0.434531
# 5         3    0  0.016510        1  0.346569
# 6         1    0  0.101229        0  0.673285
# 7         3    0  0.041136        0  0.019854
# 8         3    1  0.021731        0  0.334004
# 9         2    1  0.058694        2  0.170646
# 10        3    1  0.032596        0  0.044986
# 11        1    1  0.051822        0  0.723549
# 12        3    0  0.015713        0  0.246042
# 13        3    0  0.061045        0  0.484795
# 14        3    1  0.015330        0  0.170646
# 15        2    1  0.031230        0  0.685851
# 16        3    0  0.056848        1  0.019854
# 17        2    0  0.025374        0  0.346569
# 18        3    1  0.035134        0  0.384267
# ...

# %%
print(dataTrain[predictors])
# Out:
#      Pclass  Sex      Fare Embarked       Age
# 0         3    0  0.014151        0  0.271174
# 1         1    1  0.139136        2  0.472229
# 2         3    1  0.015469        0  0.321438
# 3         1    1  0.103644        0  0.434531
# 4         3    0  0.015713        0  0.434531
# 5         3    0  0.016510        1  0.346569
# 6         1    0  0.101229        0  0.673285
# 7         3    0  0.041136        0  0.019854
# 8         3    1  0.021731        0  0.334004
# 9         2    1  0.058694        2  0.170646
# 10        3    1  0.032596        0  0.044986
# 11        1    1  0.051822        0  0.723549
# 12        3    0  0.015713        0  0.246042
# 13        3    0  0.061045        0  0.484795
# 14        3    1  0.015330        0  0.170646
# 15        2    1  0.031230        0  0.685851
# 16        3    0  0.056848        1  0.019854
# 17        2    0  0.025374        0  0.346569
# 18        3    1  0.035134        0  0.384267
# ...

# %%
np.sum(dataTrain[predictors] == np.NaN)
# Out:
# Pclass      0
# Sex         0
# Fare        0
# Embarked    0
# Age         0
# dtype: int64

# %%
clf = SVC()

# %%
print(dataTrain[predictors])
# Out:
#      Pclass  Sex      Fare Embarked       Age
# 0         3    0  0.014151        0  0.271174
# 1         1    1  0.139136        2  0.472229
# 2         3    1  0.015469        0  0.321438
# 3         1    1  0.103644        0  0.434531
# 4         3    0  0.015713        0  0.434531
# 5         3    0  0.016510        1  0.346569
# 6         1    0  0.101229        0  0.673285
# 7         3    0  0.041136        0  0.019854
# 8         3    1  0.021731        0  0.334004
# 9         2    1  0.058694        2  0.170646
# 10        3    1  0.032596        0  0.044986
# 11        1    1  0.051822        0  0.723549
# 12        3    0  0.015713        0  0.246042
# 13        3    0  0.061045        0  0.484795
# 14        3    1  0.015330        0  0.170646
# 15        2    1  0.031230        0  0.685851
# 16        3    0  0.056848        1  0.019854
# 17        2    0  0.025374        0  0.346569
# 18        3    1  0.035134        0  0.384267
# ...

# %%
linreg = LinerRegression()
	linreg.fit(dataTrain[predictors], dataTrain['Survived'])
# Out:
#   File "<ipython-input-29-e0d248bf0f44>", line 2
#     linreg.fit(dataTrain[predictors], dataTrain['Survived'])
#     ^
# IndentationError: unexpected indent

# %%
linreg = LinerRegression()
linreg.fit(dataTrain[predictors], dataTrain['Survived'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-c6ff70bf4f1f> in <module>()
# ----> 1 linreg = LinerRegression()
#       2 linreg.fit(dataTrain[predictors], dataTrain['Survived'])
#
# NameError: name 'LinerRegression' is not defined

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()
linreg.fit(dataTrain[predictors], dataTrain['Survived'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-bca251972ba0> in <module>()
#       1 linreg = LinearRegression()
# ----> 2 linreg.fit(dataTrain[predictors], dataTrain['Survived'])
#
# /usr/local/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
dataTrain[predictors]
# Out:
#      Pclass  Sex      Fare Embarked       Age
# 0         3    0  0.014151        0  0.271174
# 1         1    1  0.139136        2  0.472229
# 2         3    1  0.015469        0  0.321438
# 3         1    1  0.103644        0  0.434531
# 4         3    0  0.015713        0  0.434531
# 5         3    0  0.016510        1  0.346569
# 6         1    0  0.101229        0  0.673285
# 7         3    0  0.041136        0  0.019854
# 8         3    1  0.021731        0  0.334004
# 9         2    1  0.058694        2  0.170646
# 10        3    1  0.032596        0  0.044986
# 11        1    1  0.051822        0  0.723549
# 12        3    0  0.015713        0  0.246042
# 13        3    0  0.061045        0  0.484795
# 14        3    1  0.015330        0  0.170646
# 15        2    1  0.031230        0  0.685851
# 16        3    0  0.056848        1  0.019854
# 17        2    0  0.025374        0  0.346569
# 18        3    1  0.035134        0  0.384267
# ...

# %%
dataTrain['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
dataTrain[predictors].to_csv('~/Desktop/out.csv',index=False,header=False)
